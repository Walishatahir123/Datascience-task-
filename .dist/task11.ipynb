# %%
# Import libraries
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# Download stopwords
nltk.download('stopwords')

# Sample text
documents = [
    "Natural language processing is fun.",
    "NLP allows computers to understand human language."
]

# Stopwords
stop_words = set(stopwords.words('english'))

# Tokenization and stopword removal
processed_docs = []
for doc in documents:
    tokens = [word.lower() for word in doc.split() if word.lower() not in stop_words]
    processed_docs.append(' '.join(tokens))

# TF-IDF Vectorization
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(processed_docs)

# Show TF-IDF features
print("Features:", vectorizer.get_feature_names_out())
print("TF-IDF Matrix:\n", X.toarray())
# Out:
# Features: ['allows' 'computers' 'fun' 'human' 'language' 'natural' 'nlp'
#  'processing' 'understand']
# TF-IDF Matrix:
#  [[0.         0.         0.53404633 0.         0.37997836 0.53404633
#   0.         0.53404633 0.        ]
#  [0.4261596  0.4261596  0.         0.4261596  0.30321606 0.
#   0.4261596  0.         0.4261596 ]]
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
