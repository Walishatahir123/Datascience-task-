# %%
import pandas as pd
from sklearn.datasets import load_iris
import numpy as np

# Load dataset
df=pd.read_csv('house_prices.csv')  # Example dataset

# %%
df
# Out:
#     LotArea  OverallQual  YearBuilt  TotalBsmtSF  GrLivArea  GarageCars  \
# 0      8450            7       2003          856       1710           2
# 1      9600            6       1976         1262       1262           2
# 2     11250            7       2001          920       1786           2
# 3      9550            7       1915          756       1717           3
# 4     14260            8       2000         1145       2198           3
# 5     14115            5       1993          796       1362           2
# 6     10084            5       1973         1686       1694           2
# 7     10382            7       1931          865       2090           1
# 8      6120            6       1939         1040       1774           1
# 9      7420            7       1965          938       1372           1
# 10     8500            8       2005         1200       2300           3
# 11     9000            7       2004         1056       1850           2
# 12    12000            6       2006          900       1750           2
# 13    12500            8       1998         1450       2100           3
# 14    13000            9       2010         1100       2400           3
# 15     8700            7       2002          890       1800           2
# 16     9800            6       1985         1345       1600           2
# 17    15000            9       2007         1600       2700           3
# 18     8700            6       1990         1100       1900           2
# 19    10000            7       2003          950       2000           2
# 20     9200            8       2004          980       2200           3
# 21     8900            7       2001          870       1700           2
# 22    11100            7       2005         1000       2100           2
# 23    10500            8       2007         1450       2500           3
# 24    10050            7       2009         1600       2600           3
# 25     9600            6       1995          930       1650           2
# 26    11500            7       2000         1200       2000           2
# 27    13000            8       2002         1450       2300           3
# 28     8700            6       1980          990       1500           2
# 29     9500            7       1998          980       1900           2
# 30    10100            7       1999         1200       1750           2
# 31    10800            8       2011         1400       2800           3
# 32    11300            9       2010         1500       2900           3
# 33    14000            9       2008         1300       2600           3
# 34     8700            6       1990         1100       1800           2
# 35     9700            7       2005         1050       1950           2
# 36     8800            7       1985          980       1700           2
# 37    12800            8       2009         1650       2400           3
# 38     9100            6       2003          970       1850           2
# 39     9400            7       2004         1080       1600           2
# 40    12000            8       2012         1400       2500           3
# 41     8800            6       2006         1300       2000           2
# 42     9300            7       2008         1250       2100           3
# 43     9900            7       2003         1100       1900           2
# 44     9500            6       1994          950       1550           1
# 45     8600            6       1996          960       1650           2
# 46     9100            8       2011         1000       1850           2
# 47    10700            7       2009         1180       2050           3
# 48    12300            9       2010         1600       3000           3
# 49     8900            7       2007         1120       2200           2
#
#     SalePrice
# 0      208500
# 1      181500
# 2      223500
# 3      140000
# 4      250000
# 5      143000
# 6      307000
# 7      200000
# 8      129900
# 9      118000
# 10     245000
# 11     215000
# 12     190000
# 13     275000
# 14     320000
# 15     230000
# 16     195000
# 17     330000
# 18     220000
# 19     210000
# 20     265000
# 21     225000
# 22     240000
# 23     310000
# 24     340000
# 25     200000
# 26     260000
# 27     290000
# 28     180000
# 29     210000
# 30     205000
# 31     355000
# 32     370000
# 33     340000
# 34     190000
# 35     220000
# 36     200000
# 37     300000
# 38     210000
# 39     185000
# 40     315000
# 41     250000
# 42     260000
# 43     230000
# 44     175000
# 45     180000
# 46     220000
# 47     265000
# 48     350000
# 49     270000

# %%
# -------------------------------
# Week 4: Statistical & Correlation Analysis
# -------------------------------

import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("house_prices.csv")

print("=== Dataset Overview ===")
print(df.head(), "\n")

# -------------------------------
# 1️⃣ Basic Descriptive Statistics
# -------------------------------
print("=== Basic Statistics ===")
print(df.describe().T, "\n")

# Mean, Median, Mode, Variance for each column
stats = pd.DataFrame({
    "Mean": df.mean(numeric_only=True),
    "Median": df.median(numeric_only=True),
    "Mode": df.mode(numeric_only=True).iloc[0],
    "Variance": df.var(numeric_only=True)
})

print("=== Mean, Median, Mode, Variance ===")
print(stats, "\n")

# -------------------------------
# 2️⃣ Correlation Matrix
# -------------------------------
print("=== Correlation Matrix ===")
corr = df.corr(numeric_only=True)
print(corr, "\n")

# -------------------------------
# 3️⃣ Correlation with Target Variable (SalePrice)
# -------------------------------
target_corr = corr['SalePrice'].sort_values(ascending=False)
print("=== Correlation of Features with SalePrice ===")
print(target_corr, "\n")

# -------------------------------
# 4️⃣ Identify Top 3 Predictive Features
# -------------------------------
top3 = target_corr[1:4]  # exclude SalePrice itself
print("🏆 Top 3 Features Most Related to SalePrice:")
print(top3, "\n")

# -------------------------------
# 5️⃣ Optional Visualization
# -------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='YlGnBu', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# -------------------------------
# ✅ Summary
# -------------------------------
print("""
 Week 4 Completed
- Calculated mean, median, mode, variance for numeric columns
- Performed correlation analysis
- Identified top 3 features related to SalePrice
- Ready to include in report and upload to GitHub
""")
# Out:
# === Dataset Overview ===
#    LotArea  OverallQual  YearBuilt  TotalBsmtSF  GrLivArea  GarageCars  \
# 0     8450            7       2003          856       1710           2
# 1     9600            6       1976         1262       1262           2
# 2    11250            7       2001          920       1786           2
# 3     9550            7       1915          756       1717           3
# 4    14260            8       2000         1145       2198           3
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
#
# === Basic Statistics ===
#              count       mean           std       min        25%       50%  \
# LotArea       50.0   10285.62   1869.713859    6120.0    8925.00    9750.0
# OverallQual   50.0       7.08      1.006915       5.0       6.00       7.0
# YearBuilt     50.0    1995.74     20.182646    1915.0    1994.25    2003.0
# TotalBsmtSF   50.0    1147.90    244.597232     756.0     962.50    1100.0
# GrLivArea     50.0    1999.30    404.642662    1262.0    1711.75    1900.0
# GarageCars    50.0       2.28      0.607437       1.0       2.00       2.0
# SalePrice     50.0  238828.00  61564.978250  118000.0  200000.00  224250.0
#
#                   75%       max
# LotArea       11287.5   15000.0
# OverallQual       8.0       9.0
# YearBuilt      2007.0    2012.0
# TotalBsmtSF    1300.0    1686.0
# GrLivArea      2200.0    3000.0
# GarageCars        3.0       3.0
# SalePrice    273750.0  370000.0
#
# === Mean, Median, Mode, Variance ===
#                   Mean    Median      Mode      Variance
# LotArea       10285.62    9750.0    8700.0  3.495830e+06
# OverallQual       7.08       7.0       7.0  1.013878e+00
# YearBuilt      1995.74    2003.0    2003.0  4.073392e+02
# TotalBsmtSF    1147.90    1100.0    1100.0  5.982781e+04
# GrLivArea      1999.30    1900.0    1850.0  1.637357e+05
# GarageCars        2.28       2.0       2.0  3.689796e-01
# SalePrice    238828.00  224250.0  200000.0  3.790247e+09
#
# === Correlation Matrix ===
#               LotArea  OverallQual  YearBuilt  TotalBsmtSF  GrLivArea  \
# LotArea      1.000000     0.488886   0.337138     0.415507   0.498451
# OverallQual  0.488886     1.000000   0.375622     0.407884   0.799055
# YearBuilt    0.337138     0.375622   1.000000     0.333421   0.428361
# TotalBsmtSF  0.415507     0.407884   0.333421     1.000000   0.649321
# GrLivArea    0.498451     0.799055   0.428361     0.649321   1.000000
# GarageCars   0.563141     0.663325   0.440535     0.569675   0.713122
# SalePrice    0.542357     0.687492   0.568443     0.774227   0.894879
#
#              GarageCars  SalePrice
# LotArea        0.563141   0.542357
# OverallQual    0.663325   0.687492
# YearBuilt      0.440535   0.568443
# TotalBsmtSF    0.569675   0.774227
# GrLivArea      0.713122   0.894879
# GarageCars     1.000000   0.738635
# SalePrice      0.738635   1.000000
#
# === Correlation of Features with SalePrice ===
# SalePrice      1.000000
# GrLivArea      0.894879
# TotalBsmtSF    0.774227
# GarageCars     0.738635
# OverallQual    0.687492
# YearBuilt      0.568443
# LotArea        0.542357
# Name: SalePrice, dtype: float64
#
# 🏆 Top 3 Features Most Related to SalePrice:
# GrLivArea      0.894879
# TotalBsmtSF    0.774227
# GarageCars     0.738635
# Name: SalePrice, dtype: float64
#  Week 4 Completed
# - Calculated mean, median, mode, variance for numeric columns
# - Performed correlation analysis
# - Identified top 3 features related to SalePrice
# - Ready to include in report and upload to GitHub
